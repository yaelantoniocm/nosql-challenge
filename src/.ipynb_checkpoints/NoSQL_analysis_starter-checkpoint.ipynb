# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print(f"There are {count} establishments with a hygiene score of 20.")

# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# There are 41 establishments with a hygiene score of 20.
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64e6e2144839d27f240e6bb6'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(establishments.find(query))

# Display the number of rows in the DataFrame
print(f"There are {len(df)} rows in this DataFrame.")

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# There are 41 rows in this DataFrame.
#                         _id   FHRSID  ChangesByServerID  \
# 0  64e6e2144839d27f240e6bb6   110681                  0
# 1  64e6e2154839d27f240e6f37   612039                  0
# 2  64e6e2154839d27f240e7241   730933                  0
# 3  64e6e2154839d27f240e742f   172735                  0
# 4  64e6e2154839d27f240e743e   172953                  0
# 5  64e6e2164839d27f240e7ddd   512854                  0
# 6  64e6e2164839d27f240e7ffe  1537089                  0
# 7  64e6e2174839d27f240e9529   155648                  0
# 8  64e6e2174839d27f240e996d  1012883                  0
# 9  64e6e2184839d27f240ea17f   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query_London = {'LocalAuthorityName': {'$regex': 'London'}, 
          'RatingValue': {'$gte': 4}
         }

# Use count_documents to display the number of documents in the result
count_London = establishments.count_documents(query_London)
print(f" {count_London} establishments in London that have a RatingValue greater than or equal to 4.")

# Display the first document in the results using pprint
pprint(establishments.find_one(query_London))
# Out:
#  33 establishments in London that have a RatingValue greater than or equal to 4.
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64e6e2164839d27f240e85d1'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
df2 = pd.DataFrame(establishments.find(query_London))
# Display the number of rows in the DataFrame
print(f"{len(df2)} rows in total.")
# Display the first 10 rows of the DataFrame
df2.head(10)
# Out:
# 33 rows in total.
#                         _id   FHRSID  ChangesByServerID  \
# 0  64e6e2164839d27f240e85d1   621707                  0
# 1  64e6e2164839d27f240e88f7  1130836                  0
# 2  64e6e2174839d27f240e9444   293783                  0
# 3  64e6e2184839d27f240ea244  1315095                  0
# 4  64e6e2184839d27f240ea245   294474                  0
# 5  64e6e2184839d27f240ea94d   294900                  0
# 6  64e6e21a4839d27f240eca5b   293756                  0
# 7  64e6e21a4839d27f240ece22   878523                  0
# 8  64e6e21a4839d27f240ece3c   293772                  0
# 9  64e6e21a4839d27f240ece3d   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000002585         The Nuance Group (UK) Limited
# 9             PI/000016185                              WH Smith
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                  Duty Free Shop Passenger Terminal
# 9                                London City Airport
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                               Tilbury     Charlton  ...
# 4                         Tilbury Essex               ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8  London City AirportRoyal DocksLondon               ...
# 9                     Silvertown London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8     {'longitude': 0.047966, 'latitude': 51.504112}
# 9  {'longitude': 0.0479655750095844, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188826            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

# Define the filter and sort criteria
query_Penang_Flavours = {
    "geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
    "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search},
    "RatingValue": 5
}

sort_criteria = [("scores.Hygiene", 1)]  # Sort in ascending order by hygiene score

# Perform the search and sort
results = establishments.find(query_Penang_Flavours).sort(sort_criteria)

# Print the results
for result in results:
    print("BusinessName:", result.get("BusinessName"))
    print("Latitude:", result.get("geocode").get("latitude"))
    print("Longitude:", result.get("geocode").get("longitude"))
    print("RatingValue:", result.get("RatingValue"))
    print("Hygiene Score:", result.get("scores").get("Hygiene"))
    print("---")
# Out:
# BusinessName: Iceland
# Latitude: 51.4871482849121
# Longitude: 0.0924199968576431
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Howe and Co Fish and Chips - Van 17
# Latitude: 51.4875335693359
# Longitude: 0.0925370007753372
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Volunteer
# Latitude: 51.4873437
# Longitude: 0.09208
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Plumstead Manor Nursery
# Latitude: 51.481517791748
# Longitude: 0.0859939977526665
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Atlantic Fish Bar
# Latitude: 51.4867296
# Longitude: 0.0912164
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Lumbini Grocery Ltd T/A Al-Iman
# Latitude: 51.4871632
# Longitude: 0.0916256
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Greggs
# Latitude: 51.4871406555176
# Longitude: 0.0912820026278496
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Tesco
# Latitude: 51.4871406555176
# Longitude: 0.0912820026278496
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Dosa & Sambal Express
# Latitude: 51.4877576
# Longitude: 0.091566
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Abbi Wines
# Latitude: 51.4871401
# Longitude: 0.0908895
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Dilkush Tandoori
# Latitude: 51.4878941
# Longitude: 0.0909672
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Dadoo's Foodstore
# Latitude: 51.4876894
# Longitude: 0.0905233
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: High Street News & Wine
# Latitude: 51.4876718
# Longitude: 0.0903232
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: The Old Mill
# Latitude: 51.4817109
# Longitude: 0.0840959
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: The Belfry
# Latitude: 51.487928
# Longitude: 0.0900757
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Chick Chicken
# Latitude: 51.4880687
# Longitude: 0.0897508
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Conway Primary School
# Latitude: 51.487865447998
# Longitude: 0.0894860029220581
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Best Halal Meat Limited
# Latitude: 51.4881611
# Longitude: 0.089611
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Boba & Co UK
# Latitude: 51.4881627
# Longitude: 0.0895246
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Poundland
# Latitude: 51.4884195010951
# Longitude: 0.0893575026992294
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: SD News & Mini Market
# Latitude: 51.4827461242676
# Longitude: 0.0831020027399063
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: KFC
# Latitude: 51.4884997
# Longitude: 0.0887766
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Co-op Food
# Latitude: 51.4806876203642
# Longitude: 0.0808583091748281
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Ambala & Karahi Ltd
# Latitude: 51.4885934
# Longitude: 0.0885648
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Los carnales mexicanos
# Latitude: 51.4810979
# Longitude: 0.0802144
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: East Plumstead Pre School
# Latitude: 51.4845542907715
# Longitude: 0.0836590006947517
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Plumstead Common Petrol Station
# Latitude: 51.4806732
# Longitude: 0.0793165
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: My Home (Plumstead)
# Latitude: 51.4860247
# Longitude: 0.0843422
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Deescon Freight
# Latitude: 51.4890121
# Longitude: 0.0868772
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: St Patricks Social Club
# Latitude: 51.487438
# Longitude: 0.0852709
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Star INN
# Latitude: 51.4808120727539
# Longitude: 0.0785060003399849
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Bear Hugs Day Nursery
# Latitude: 51.4838756
# Longitude: 0.0812914
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Roundhouse Food and Wine
# Latitude: 51.4847465
# Longitude: 0.0820677
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: U&A Foods Ltd
# Latitude: 51.4892023
# Longitude: 0.086187
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: St. Patrick's School
# Latitude: 51.4884185791016
# Longitude: 0.0853480026125908
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Kings Cafe
# Latitude: 51.4892216
# Longitude: 0.0861158
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Peace Manor Residential Care
# Latitude: 51.484673
# Longitude: 0.0814574
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: The Eggfree Cake Box (Plumstead)
# Latitude: 51.4896464707035
# Longitude: 0.0857344851907352
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Danfe Restaurant
# Latitude: 51.4893348
# Longitude: 0.0853618
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: McDonald's
# Latitude: 51.4908567
# Longitude: 0.0853967
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Jhas Catering Services
# Latitude: 51.4900815
# Longitude: 0.0842824
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Wilson & Bay Coffee Club
# Latitude: 51.4897501
# Longitude: 0.0839053
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: D J Off Licence
# Latitude: 51.4862246
# Longitude: 0.0801741
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Suya Academy Ltd
# Latitude: 51.4901495
# Longitude: 0.0839974
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Waterside Primary School
# Latitude: 51.4873504638672
# Longitude: 0.0810069963335991
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Om Stop & Go
# Latitude: 51.4835927
# Longitude: 0.0771598
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: The Rose Inn
# Latitude: 51.486075
# Longitude: 0.0789717
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Greenwich Islamic Centre
# Latitude: 51.4903258
# Longitude: 0.0824813
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: St Margaret's C of E Primary School
# Latitude: 51.4824142456055
# Longitude: 0.074412003159523
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Bal Krishna Nursery
# Latitude: 51.4824256896973
# Longitude: 0.0743729993700981
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Quaggy at Margaret Bondfield
# Latitude: 51.4863967895508
# Longitude: 0.0776320025324821
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Fresh Chances
# Latitude: 51.4863955
# Longitude: 0.0776292
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Tesco
# Latitude: 51.4989512
# Longitude: 0.0902181
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Domino's Pizza
# Latitude: 51.4987492
# Longitude: 0.0895991
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Ashgreen House
# Latitude: 51.4871520996094
# Longitude: 0.075984999537468
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Heronsgate Primary School Thamesmead Campus
# Latitude: 51.4940567016602
# Longitude: 0.0827509984374046
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Breakfast Club
# Latitude: 51.4950485229492
# Longitude: 0.0835620015859604
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: BR6
# Latitude: 51.4903331
# Longitude: 0.0787421
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Catering & Hospitality Education Dep
# Latitude: 51.4903331
# Longitude: 0.0787421
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: The Real Deal
# Latitude: 51.4978398
# Longitude: 0.0844204
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Borna
# Latitude: 51.4918377
# Longitude: 0.0774802
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Blossom Place Olive Services
# Latitude: 51.4942476
# Longitude: 0.0795886
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Menagerie Cafe
# Latitude: 51.4914321899414
# Longitude: 0.075545996427536
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Innova Nutraceutics Ltd
# Latitude: 51.4935863
# Longitude: 0.0770593
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Foodelo
# Latitude: 51.4923133850098
# Longitude: 0.0744580030441284
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: Brighter Futures Project
# Latitude: 51.4922421
# Longitude: 0.0739989
# RatingValue: 5
# Hygiene Score: 0
# ---
# BusinessName: TIWA N TIWA African Restaurant Ltd
# Latitude: 51.4870351
# Longitude: 0.0927429
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Fineway Cash & Carry
# Latitude: 51.4876089
# Longitude: 0.0909382
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Lucky Food & Wine
# Latitude: 51.4878934
# Longitude: 0.0910104
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Premier Express
# Latitude: 51.4877234
# Longitude: 0.0904552
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Everest Stores Ltd
# Latitude: 51.4876718
# Longitude: 0.0903232
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: The Plumstead Pantry
# Latitude: 51.4817727
# Longitude: 0.083745
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Spice Island
# Latitude: 51.4804420471191
# Longitude: 0.0812250003218651
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Apna Grill
# Latitude: 51.4870876
# Longitude: 0.0857591
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Flames Kebab Ltd trading as Morley's
# Latitude: 51.4810714
# Longitude: 0.0796803
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Conway Road Supermarket
# Latitude: 51.4873374
# Longitude: 0.0858713
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: The Plum Tree Beer Shop
# Latitude: 51.4808287
# Longitude: 0.078661
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Chef's House
# Latitude: 51.4808120727539
# Longitude: 0.0785060003399849
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Cafe Deluxe
# Latitude: 51.4891019
# Longitude: 0.0857646
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Malai Restaurant/Ghandi's/Sweet Sensationz/JusBoba
# Latitude: 51.489315
# Longitude: 0.0859184
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Mr Uncles Kebab
# Latitude: 51.4893255
# Longitude: 0.0858325
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Plumstead Radical Club
# Latitude: 51.4893112182617
# Longitude: 0.084697000682354
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Nisa Local
# Latitude: 51.4861922
# Longitude: 0.0809311
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Brew Station
# Latitude: 51.4899426
# Longitude: 0.0846755
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: GMT Kitchen and Cafe
# Latitude: 51.4903331
# Longitude: 0.0787421
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: Heronsgate Primary School Royal Arsenal Campus
# Latitude: 51.4898490905762
# Longitude: 0.074074998497963
# RatingValue: 5
# Hygiene Score: 5
# ---
# BusinessName: PLOT Roasting
# Latitude: 51.4935863
# Longitude: 0.0770593
# RatingValue: 5
# Hygiene Score: 5
# ---

# %%
# Convert result to Pandas DataFrame
pd.DataFrame(establishments.find(query_Penang_Flavours).sort(sort_criteria).limit(5))
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64e6e21a4839d27f240ec415   694609                  0
# 1  64e6e21a4839d27f240ec42d   695241                  0
# 2  64e6e21a4839d27f240ec430   694478                  0
# 3  64e6e21a4839d27f240ec3e8   695223                  0
# 4  64e6e21a4839d27f240ec3f8  1380578                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000086506                    Atlantic Fish Bar
# 3             PI/000178842                              Iceland
# 4                    14425  Howe and Co Fish and Chips - Van 17
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                        Caring Premises               5
# 2                 Takeaway/sandwich shop            7844
# 3  Retailers - supermarkets/hypermarkets            7840
# 4                         Mobile caterer            7846
#
#                                         AddressLine1 AddressLine2  \
# 0                    130 - 132 Plumstead High Street
# 1               Plumstead Manor School Old Mill Road
# 2                                   35 Lakedale Road
# 3                    144 - 146 Plumstead High Street
# 4  Restaurant And Premises 107A Plumstead High St...
#
#   AddressLine3  ...             LocalAuthorityWebSite  \
# 0    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 1    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 2    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 3    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 4    Plumstead  ...  http://www.royalgreenwich.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0  health@royalgreenwich.gov.uk
# 1  health@royalgreenwich.gov.uk
# 2  health@royalgreenwich.gov.uk
# 3  health@royalgreenwich.gov.uk
# 4  health@royalgreenwich.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.09208, 'latitude': 51.4873437}
# 1  {'longitude': 0.0859939977526665, 'latitude': ...
# 2   {'longitude': 0.0912164, 'latitude': 51.4867296}
# 3  {'longitude': 0.0924199968576431, 'latitude': ...
# 4  {'longitude': 0.0925370007753372, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4646.965635            False
# 1  4646.974010            False
# 2  4646.974612            False
# 3  4646.946071            False
# 4  4646.955931            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match_query = {'$match': {'scores.Hygiene': 0}}
group_query = {'$group': {'_id': '$LocalAuthorityName', 
                          'count': {'$sum': 1}
                         }
              }
sort_query = {'$sort': {'count': -1}}

pipeline = [match_query, group_query, sort_query]

results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(f"There are {len(results)} documents in the result.")

# Print the first 10 results
pprint(results[0:10])
# Out:
# There are 55 documents in the result.
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
agg_df = pd.json_normalize(results)

# Display the number of rows in the DataFrame
print(f"There are {len(agg_df)} rows in the DataFrame.")

# Display the first 10 rows of the DataFrame
agg_df.head(10)
# Out:
# There are 55 rows in the DataFrame.
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
